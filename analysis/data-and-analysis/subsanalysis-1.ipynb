# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)

df = pd.read_csv("subs.csv")
df.head()
# Out:
#    SubmissionID ReceiptDate ValidationDate   DeregDate DeregEffDate SubType  \
# 0           162  1999-03-29     1999-03-29         NaN          NaN       F
# 1           163  1999-03-29     1999-03-29         NaN          NaN       F
# 2           166  1999-03-29     1999-03-29         NaN          NaN       F
# 3           168  1999-03-29     1999-03-29  2005-03-16   2005-01-01       F
# 4           169  1999-03-29     1999-04-13         NaN          NaN       F
#
#   SubReason  EPAFacilityID                                           FacName  \
# 0       NaN   100000001419  Schuyler Cooperative Assn. Anhydrous North Plant
# 1       NaN   100000001437    Schuyler Cooperative Assn. - Richland Location
# 2       NaN   100000001473                     Oneida Valley Treatment Plant
# 3       NaN   100000001428                           East Brady Pump Station
# 4       NaN   100000001446                                      O'Toole Inc.
#
# ...

# %%
df.SubType.value_counts()
# Out:
# R    57426
# F    21118
# C    11529
# Name: SubType, dtype: int64

# %%
df.ReceiptDate.median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/nanops.py:760, in nanmedian(values, axis, skipna, mask)
#     759 try:
# --> 760     values = values.astype("f8")
#     761 except ValueError as err:
#     762     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: '1999-03-29'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /Users/torylysik/Desktop/codestuff/TBL-rpm-2023/data-and-analysis/subsanalysis-1.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/torylysik/Desktop/codestuff/TBL-rpm-2023/data-and-analysis/subsanalysis-1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df.ReceiptDate.median()
#
# ...

# %%
df.NumAccidents.value_counts()
df.NumAccidents.hist()
