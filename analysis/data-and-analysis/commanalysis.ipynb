# %%
import pandas as pd
import os
import numpy as np
import pandas as pd
df = pd.read_csv('communities.csv')
df.head()
# Out:
# /var/folders/_f/4k_f80ps0t92rc8yl4cc06x00000gp/T/ipykernel_56107/2300455398.py:5: DtypeWarning: Columns (18,26,70,72,85,131) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('communities.csv')
#    Census tract 2010 ID     County Name State/Territory  \
# 0            1001020100  Autauga County         Alabama
# 1            1001020200  Autauga County         Alabama
# 2            1001020300  Autauga County         Alabama
# 3            1001020400  Autauga County         Alabama
# 4            1001020500  Autauga County         Alabama
#
#    Percent Black or African American alone  \
# 0                                     0.07
# 1                                     0.57
# 2                                     0.24
# 3                                     0.05
# 4                                     0.18
#
#    Percent American Indian / Alaska Native  Percent Asian  \
# 0                                      0.0           0.00
# ...

# %%
df.rename(columns = 'Identified as disadvantaged')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/torylysik/Desktop/codestuff/TBL-rpm-2023/data-and-analysis/commanalysis.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/torylysik/Desktop/codestuff/TBL-rpm-2023/data-and-analysis/commanalysis.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df['comunities.csv'] = df.groupby('Identified as disadvantaged')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
# ...
